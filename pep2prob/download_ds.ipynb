# %%
## DOWNLOAD DATASET FROM HUGGINGFACE HUB
from huggingface_hub import snapshot_download

# %%
local_dir = "../data/Pep2Prob"
cache_dir = "../.cache"
dataset_name = "bandeiralab/Pep2Prob"

local_path = snapshot_download(
    repo_id=dataset_name,
    repo_type="dataset",
    local_dir=local_dir,
    local_dir_use_symlinks=False,
    cache_dir=cache_dir,
)
# Out:
# e:\Dai hoc\2526I\dacn\flow-matching\venv\Lib\site-packages\huggingface_hub\utils\_validators.py:202: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `snapshot_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# Fetching 15 files: 100%|██████████| 15/15 [01:24<00:00,  5.61s/it]
