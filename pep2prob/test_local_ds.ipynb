# %%
import os
os.getcwd()
# Out:
# 'e:\\Dai hoc\\2526I\\dacn\\flow-matching\\pep2prob'

# %%
from p2p_dataset import Pep2ProbDataset

# %%
ds = Pep2ProbDataset(data_dir="data")
# Out:
# ...
# Download complete.
# ...
# Test indices download complete.
# ...
# Train indices download complete.
# ...
# Test indices download complete.
# ...
# Train indices download complete.
# ...
# Test indices download complete.
# ...
# Train indices download complete.
# ...
# Test indices download complete.
# ...
# Train indices download complete.
# ...
# Test indices download complete.
# ...
# Train indices download complete.
# Dataset and data split downloaded successfully.
